# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_style("darkgrid", {"axes.facecolor": ".96"})
import warnings
warnings.filterwarnings('ignore')

# %%
bmi_raw = pd.read_csv('BMI.csv')
print(bmi_raw.shape)
print(bmi_raw.isna().sum())
# Out:
# (2111, 17)
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
bmi_raw.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
bmi_raw["BMI"] = bmi_raw["Weight"]/(bmi_raw["Height"]**2)

# %%
pd.crosstab(pd.cut(bmi_raw["BMI"], bins=[15,18.5,25,30,35,40,100]), bmi_raw["NObeyesdad"])
# Out:
# NObeyesdad     Insufficient_Weight  Normal_Weight  Obesity_Type_I  \
# BMI
# (15.0, 18.5]                   264              3               0
# (18.5, 25.0]                     4            284               0
# (25.0, 30.0]                     0              0               2
# (30.0, 35.0]                     0              0             346
# (35.0, 40.0]                     0              0               3
# (40.0, 100.0]                    0              0               0
#
# NObeyesdad     Obesity_Type_II  Obesity_Type_III  Overweight_Level_I  \
# BMI
# (15.0, 18.5]                 0                 0                   0
# (18.5, 25.0]                 0                 0                  12
# (25.0, 30.0]                 0                 0                 278
# (30.0, 35.0]                18                 0                   0
# (35.0, 40.0]               279                56                   0
# (40.0, 100.0]                0               268                   0
#
# NObeyesdad     Overweight_Level_II
# BMI
# (15.0, 18.5]                     0
# (18.5, 25.0]                     0
# (25.0, 30.0]                   286
# (30.0, 35.0]                     4
# (35.0, 40.0]                     0
# (40.0, 100.0]                    0

# %%
bmi_raw = bmi_raw.drop("NObeyesdad", axis=1)

# %%
bmi_raw.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# BMI                               float64
# dtype: object

# %%
binary_columns = bmi_raw.nunique() == 2
binary_columns = binary_columns[binary_columns].index.tolist()
binary_columns
# Out:
# ['Gender', 'family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']

# %%
# imbalanced classes, outliers detection

# %%
bmi_raw.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'BMI'],
#       dtype='object')

# %%
bmi_raw = bmi_raw.rename(columns= 
    {
    "Gender": "gender",
    "Age": "age",
    "Height": "height",
    "Weight": "weight",    
    "FAVC": "frequent_high_calorie_food",      # Do you eat high-calorie food frequently?
    "FCVC": "vegetable_consumption_freq",      # Do you usually eat vegetables in your meals?
    "NCP": "main_meals_per_day",               # Number of main meals
    "CAEC": "eating_between_meals",            # Do you eat any food between meals?
    "CH2O": "water_intake",                    # How much water do you drink daily?
    "SCC": "calorie_monitoring",               # Do you monitor the calories you eat?
    "FAF": "physical_activity_freq",           # How often do you have physical activity?
    "TUE": "screen_time",                      # Time using technology devices
    "CALC": "alcohol_consumption",             # How often do you drink alcohol?
    "MTRANS": "transportation_type",           # Which transportation do you usually use?
    "SMOKE": "smoke"                           # Do you smoke? 
    }
)
bmi_raw.head()
# Out:
#    gender   age  height  weight family_history_with_overweight  \
# 0  Female  21.0    1.62    64.0                            yes
# 1  Female  21.0    1.52    56.0                            yes
# 2    Male  23.0    1.80    77.0                            yes
# 3    Male  27.0    1.80    87.0                             no
# 4    Male  22.0    1.78    89.8                             no
#
#   frequent_high_calorie_food  vegetable_consumption_freq  main_meals_per_day  \
# 0                         no                         2.0                 3.0
# 1                         no                         3.0                 3.0
# 2                         no                         2.0                 3.0
# 3                         no                         3.0                 3.0
# 4                         no                         2.0                 1.0
#
#   eating_between_meals smoke  water_intake calorie_monitoring  \
# 0            Sometimes    no           2.0                 no
# 1            Sometimes   yes           3.0                yes
# 2            Sometimes    no           2.0                 no
# 3            Sometimes    no           2.0                 no
# 4            Sometimes    no           2.0                 no
#
#    physical_activity_freq  screen_time alcohol_consumption  \
# 0                     0.0          1.0                  no
# 1                     3.0          0.0           Sometimes
# 2                     2.0          1.0          Frequently
# 3                     2.0          0.0          Frequently
# 4                     0.0          0.0           Sometimes
#
#      transportation_type        BMI
# 0  Public_Transportation  24.386526
# 1  Public_Transportation  24.238227
# 2  Public_Transportation  23.765432
# 3                Walking  26.851852
# 4  Public_Transportation  28.342381

# %%
bmi_raw.describe()
# Out:
#                age       height       weight  vegetable_consumption_freq  \
# count  2111.000000  2111.000000  2111.000000                 2111.000000
# mean     24.312600     1.701677    86.586058                    2.419043
# std       6.345968     0.093305    26.191172                    0.533927
# min      14.000000     1.450000    39.000000                    1.000000
# 25%      19.947192     1.630000    65.473343                    2.000000
# 50%      22.777890     1.700499    83.000000                    2.385502
# 75%      26.000000     1.768464   107.430682                    3.000000
# max      61.000000     1.980000   173.000000                    3.000000
#
#        main_meals_per_day  water_intake  physical_activity_freq  screen_time  \
# count         2111.000000   2111.000000             2111.000000  2111.000000
# mean             2.685628      2.008011                1.010298     0.657866
# std              0.778039      0.612953                0.850592     0.608927
# min              1.000000      1.000000                0.000000     0.000000
# 25%              2.658738      1.584812                0.124505     0.000000
# 50%              3.000000      2.000000                1.000000     0.625350
# 75%              3.000000      2.477420                1.666678     1.000000
# max              4.000000      3.000000                3.000000     2.000000
#
#                BMI
# count  2111.000000
# mean     29.700159
# std       8.011337
# min      12.998685
# 25%      24.325802
# 50%      28.719089
# 75%      36.016501
# max      50.811753

# %%
# Plot histogram grid
bmi_raw.hist(figsize=(13,13))

# Clear the text "residue"
plt.show()

# %%
# Plot bar plot for each categorical feature
for feature in bmi_raw.dtypes[bmi_raw.dtypes == 'object'].index:
    sns.countplot(
                  y=feature, 
                  data=bmi_raw,
                  hue=feature,
                  palette=sns.color_palette("Set2")  
)
    sns.despine()
    plt.show()

# %%
 # alcohol_consupmtion and transportation_type variables have sparse classes, consider joining or dropping

# %%
bmi_raw.plot(kind='box', figsize=(14,14), subplots=True, layout=(5,4), sharex=False, sharey=False)
plt.tight_layout()  
plt.show()

# %%
# age has very skewed distribution

# %%
plt.figure(figsize = (7,7))
numeric_df = bmi_raw.select_dtypes(include='number')
corr = numeric_df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask = mask, robust = True, center = 0,square = True, cmap="coolwarm",linewidths = .6)
plt.title('Correlation Table')
sns.set_style('white')
plt.show()

# %%
# Korelace všech sloupců vůči BMI
corr_with_bmi = numeric_df.corr()['BMI'].drop('BMI')  
corr_with_bmi_sorted = corr_with_bmi.sort_values()    

plt.figure(figsize=(10,6))
corr_with_bmi_sorted.plot(kind='bar')
plt.ylabel('Correlation with BMI')
plt.title('Correlation of Features with BMI')
plt.xticks(rotation=45)
plt.show()

# %%
# consider dropping weight and height, unification of colour scales, dropping duplicates

# https://www.kaggle.com/code/pmrich/obesitydataset-eda-data-prep-ml-hypertuning   nice EDA
